# %% [markdown]
# <a href="https://colab.research.google.com/github/isaabelliz/EstudandoProgFrontend/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome_funcionario = "João Silva"
idade = 30
salario = 5000.00
cargo = "Analista de Marketing"
turno = "matutino"
setor = "Marketing"

nome_escola = "Escola Estadual ABC"
estado = "São Paulo"
numero_professores = 50
cidade = "São Paulo"
numero_militares = 10
logradouro = "Rua das Flores"
numero_endereco = "123"
numero_alunos = 1000
colegio_militar = False
disciplinas = ["Matemática", "Português", "História", "Ciências"]

print(f"Nome da escola: {nome_escola}")
print(f"Estado: {estado}")
print(f"Número de professores: {numero_professores}")
print(f"Cidade: {cidade}")
print(f"Número de militares: {numero_militares}")
print(f"Endereço: {logradouro}, {numero_endereco}, {cidade}")
print(f"Número de alunos: {numero_alunos}")
print(f"É um colégio militar? {'Sim' if colegio_militar else 'Não'}")
print("Disciplinas:")
for disciplina in disciplinas:
    print(f"- {disciplina}")

    valor1 = 10
valor2 = 5
valor3 = "2"
valor4 = 8
valor5 = -5

print("valor1 + valor2:", valor1 + valor2)
print("valor1 + valor2 + valor4:", valor1 + valor2 + valor4)
print("valor1 + valor2 - valor5:", valor1 + valor2 - valor5)

print("valor1 + int(valor3):", valor1 + int(valor3))
print("valor1 * valor2:", valor1 * valor2)
print("(valor4 * valor2) / 2:", (valor4 * valor2) / 2)

print("(valor1 + valor2 + valor4 + valor5) / 4:", (valor1 + valor2 + valor4 + valor5) / 4)

v1 = 2
v2 = 3
v3 = 5
v4 = 6

soma = v1 + v2 + v3 + v4

media = soma / 4

print("Soma dos valores:", soma)
print("Média dos valores:", media)


lista = [0, 1, 2, 3, 4, 5]

for valor in lista:
    print(valor)

    notas = [0]

notas[0] = 80

notas.append(60)
notas.append(30)
notas.append(40)
notas.append(80)
notas.append(90)

print("Notas após adicionar novos elementos:", notas)

notas.pop()
notas.pop()

print("Notas após remover os 2 últimos elementos:", notas)

notas = [60, 55, 80, 90, 59, 30]


def exercicio1(valorNota):
    if valorNota >= 60:
        print(f"A nota {valorNota} é maior ou igual a 60.")
    else:
        print(f"A nota {valorNota} é menor que 60.")


for nota in notas:
    exercicio1(nota)

notas = [60, 55, 80, 90, 59, 30]

def exercicio1(valorNota):
    if valorNota >= 60:
        print(f"A nota {valorNota} é maior ou igual a 60.")
    else:
        print(f"A nota {valorNota} é menor que 60.")

for nota in notas:
    exercicio1(nota)

    lista1 = [1, 3, 5, 7]
lista2 = [2, 4, 6, 8, 10, 12]
lista3 = [10, 20, 30]
lista4 = [11, 22, 33, 44, 55, 66, 77]
lista5 = [70, 60, 50, 40, 30, 20, 10, 5, 0]

print("Lista 1:")
for elemento in lista1:
    print(elemento)

print("\nLista 2:")
for elemento in lista2:
    print(elemento)

print("\nLista 3:")
for elemento in lista3:
    print(elemento)

print("\nLista 4:")
for elemento in lista4:
    print(elemento)

print("\nLista 5:")
for elemento in lista5:
    print(elemento)

notas_escolares = [85, 42, 78, 90, 55, 60, 49, 73, 88, 35]

for nota in notas_escolares:
    if nota >= 60:
        print(f"Aprovado: {nota}")
    else:
        print(f"Reprovado: {nota}")

notas_escolares = [85, 42, 78, 90, 55, 60, 49, 73, 88, 35]

for nota in notas_escolares:
    if nota > 80:
        print(f"Aluno foi aprovado com certificado: {nota}")
    elif nota >= 60:
        print(f"Aluno apenas aprovado: {nota}")
    else:
        print(f"Aluno reprovado: {nota}")

def exemplo(parametro):
    print(parametro)

exemplo("Olá, mundo!")
exemplo(42)
exemplo([1, 2, 3])

def imprimir_valores(valor1, valor2):
    print(valor1)
    print(valor2)

valor1 = 10
valor2 = "Hello, world!"

imprimir_valores(valor1, valor2)

def imprimir_dados_aluno(nome, idade, nota1, nota2):
    print("O aluno:", nome)
    print("Tem a idade:", idade)
    print("Nota 1:", nota1)
    print("Nota 2:", nota2)

def main():
    nome_aluno = input("Digite o nome do aluno: ")
    idade_aluno = int(input("Digite a idade do aluno: "))
    nota1_aluno = float(input("Digite a nota 1 do aluno: "))
    nota2_aluno = float(input("Digite a nota 2 do aluno: "))

    imprimir_dados_aluno(nome_aluno, idade_aluno, nota1_aluno, nota2_aluno)

if __name__ == "__main__":
    main()

    def verificar_aprovacao(nome, idade, nota1, nota2, nota3):

        print("O aluno está aprovado!")
        print("O aluno está reprovado.")

def main():
    nome_aluno = input("Digite o nome do aluno: ")
    idade_aluno = int(input("Digite a idade do aluno: "))
    nota1_aluno = float(input("Digite a nota 1 do aluno: "))
    nota2_aluno = float(input("Digite a nota 2 do aluno: "))
    nota3_aluno = float(input("Digite a nota 3 do aluno: "))

    verificar_aprovacao(nome_aluno, idade_aluno, nota1_aluno, nota2_aluno, nota3_aluno)

if __name__ == "__main__":
    main()
# Out:
# Nome da escola: Escola Estadual ABC
# Estado: São Paulo
# Número de professores: 50
# Cidade: São Paulo
# Número de militares: 10
# Endereço: Rua das Flores, 123, São Paulo
# Número de alunos: 1000
# É um colégio militar? Não
# Disciplinas:
# - Matemática
# - Português
# - História
# - Ciências
# valor1 + valor2: 15
# valor1 + valor2 + valor4: 23
# valor1 + valor2 - valor5: 20
# valor1 + int(valor3): 12
# valor1 * valor2: 50
# (valor4 * valor2) / 2: 20.0
# (valor1 + valor2 + valor4 + valor5) / 4: 4.5
# Soma dos valores: 16
# Média dos valores: 4.0
# 0
# 1
# 2
# 3
# 4
# 5
# Notas após adicionar novos elementos: [80, 60, 30, 40, 80, 90]
# Notas após remover os 2 últimos elementos: [80, 60, 30, 40]
# A nota 60 é maior ou igual a 60.
# A nota 55 é menor que 60.
# A nota 80 é maior ou igual a 60.
# A nota 90 é maior ou igual a 60.
# A nota 59 é menor que 60.
# A nota 30 é menor que 60.
# A nota 60 é maior ou igual a 60.
# A nota 55 é menor que 60.
# A nota 80 é maior ou igual a 60.
# ...
