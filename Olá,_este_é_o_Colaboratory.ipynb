# %% [markdown]
# <a href="https://colab.research.google.com/github/isaabelliz/EstudandoProgFrontend/blob/main/Ol%C3%A1%2C_este_%C3%A9_o_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idades = [20, 25, 18, 30, 22, 35, 27]

print(idades[0])
print(idades[1])
print(idades[2])
print(idades[3])
print(idades[4])
print(idades[5])

idades = (20, 25, 18, 30, 22, 35, 27)

print(idades[0])
print(idades[1])
print(idades[2])
print(idades[3])
print(idades[4])
print(idades[5])
print(idades[6])

lista = [1, 2, 3]

lista.append(5)
lista.append(8)
lista.append(10)
lista.append(-8)
lista.append(60)
lista.append(-37)

lista = [1,2,3,7,9,11,15]

lista.remove(2)
lista.remove(3)
lista.remove(9)

nomes = ["Ana", "João", "Maria", "Pedro"]
numeros = [1, 2, 3, 4, 5]
frutas = ["maçã", "banana"]
precos = [10.99, 20.49, 5.75, 8.30, 2.30, 8.30, 2]
valores_booleanos = [True]

tamanho_nomes = len(nomes)
tamanho_numeros = len(numeros)
tamanho_frutas = len(frutas)
tamanho_precos = len(precos)
tamanho_valores_booleanos = len(valores_booleanos)

print("Tamanho da lista 'nomes':", tamanho_nomes)
print("Tamanho da lista 'numeros':", tamanho_numeros)
print("Tamanho da lista 'frutas':", tamanho_frutas)
print("Tamanho da lista 'precos':", tamanho_precos)
print("Tamanho da lista 'valores_booleanos':", tamanho_valores_booleanos)

lista_int = [1, 2, 3, 4, 5]
lista_float = [1.1, 2.2, 3.3, 4.4]
outra_lista_int = [10, 20, 30, 40, 50, 60]
outra_lista_string = ["dog", "cat", "mouse", "rabbit"]

# Percorrendo e imprimindo os valores de cada lista
print("Valores da lista lista_int:")
for item in lista_int:
    print(item)

print("\nValores da lista lista_float:")
for item in lista_float:
    print(item)

print("\nValores da lista outra_lista_int:")
for item in outra_lista_int:
    print(item)

print("\nValores da lista outra_lista_string:")
for item in outra_lista_string:
    print(item)
# Out:
# 20
# 25
# 18
# 30
# 22
# 35
# 20
# 25
# 18
# 30
# 22
# 35
# 27
# Tamanho da lista 'nomes': 4
# Tamanho da lista 'numeros': 5
# Tamanho da lista 'frutas': 2
# Tamanho da lista 'precos': 7
# Tamanho da lista 'valores_booleanos': 1
# Valores da lista lista_int:
# 1
# 2
# 3
# 4
# 5
#
# Valores da lista lista_float:
# 1.1
# 2.2
# 3.3
# 4.4
#
# Valores da lista outra_lista_int:
# 10
# 20
# 30
# 40
# 50
# 60
#
# Valores da lista outra_lista_string:
# dog
# cat
# mouse
# rabbit
